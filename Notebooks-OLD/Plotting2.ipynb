# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\OneDrive\\Desktop\\Plot'

# %%
rice_df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Plot\\Year_wise.csv")
rice_df
# Out:
#    Element Aman_Rice AUS_Rice Boro_Rice Gross_Area Aman_Production  \
# 0     Year    Lac_Ha   Lac_Ha    Lac_Ha     Lac_Ha       Lac_M.Ton
# 1     1961     48.34     28.8      7.66       84.8           78.54
# 2     1962     49.53     29.5      7.87       86.9           72.44
# 3     1963     51.36     30.6      8.14       90.1           86.76
# 4     1964      52.6    31.38      8.32       92.3           85.77
# ..     ...       ...      ...       ...        ...             ...
# 56    2016       NaN      NaN       NaN     116.15             NaN
# 57    2017       NaN      NaN       NaN     115.15             NaN
# 58    2018       NaN      NaN       NaN     115.16             NaN
# 59    2019       NaN      NaN       NaN     115.17             NaN
# 60     NaN       NaN      NaN       NaN        NaN             NaN
#
#    AUS_Production Boro_Production Total_Production Average_Yeild_Rate  \
# 0       Lac_M.Ton       Lac_M.Ton        Lac_M.Ton           M.Ton/Ha
# 1            37.4           14.97           130.91               1.54
# 2           34.49           12.59           120.73               1.39
# 3           41.31           16.53            144.6                1.6
# 4           40.84           14.91           142.95               1.55
# ..            ...             ...              ...                ...
# 56            NaN             NaN           407.83              3.511
# 57            NaN             NaN           441.36              3.832
# 58            NaN             NaN           443.79              3.853
# 59            NaN             NaN           445.33              3.866
# 60            NaN             NaN              NaN                NaN
#
#    Temperature Rainfall
# 0      Celsius       MM
# 1        25.18   211.68
# 2        25.16   179.08
# 3        25.28   189.57
# 4        25.44   209.28
# ..         ...      ...
# 56       25.73   176.64
# 57        25.5   228.56
# 58       25.11   151.89
# 59       25.44   169.11
# 60         NaN      NaN
#
# [61 rows x 12 columns]

# %%
rice_df.dtypes
# Out:
# Element               object
# Aman_Rice             object
# AUS_Rice              object
# Boro_Rice             object
# Gross_Area            object
# Aman_Production       object
# AUS_Production        object
# Boro_Production       object
# Total_Production      object
# Average_Yeild_Rate    object
# Temperature           object
# Rainfall              object
# dtype: object

# %%
rice_df['Element'] = pd.to_numeric(rice_df['Element'],errors = 'coerce')
rice_df['Aman_Rice'] = pd.to_numeric(rice_df['Aman_Rice'],errors = 'coerce')
rice_df['AUS_Rice'] = pd.to_numeric(rice_df['AUS_Rice'],errors = 'coerce')
rice_df['Boro_Rice'] = pd.to_numeric(rice_df['Boro_Rice'],errors = 'coerce')
rice_df['Gross_Area'] = pd.to_numeric(rice_df['Gross_Area'],errors = 'coerce')
rice_df['Aman_Production'] = pd.to_numeric(rice_df['Aman_Production'],errors = 'coerce')
rice_df['AUS_Production'] = pd.to_numeric(rice_df['AUS_Production'],errors = 'coerce')
rice_df['Boro_Production'] = pd.to_numeric(rice_df['Boro_Production'],errors = 'coerce')
rice_df['Total_Production'] = pd.to_numeric(rice_df['Total_Production'],errors = 'coerce')
rice_df['Average_Yeild_Rate'] = pd.to_numeric(rice_df['Average_Yeild_Rate'],errors = 'coerce')
rice_df['Temperature'] = pd.to_numeric(rice_df['Temperature'],errors = 'coerce')
rice_df['Rainfall'] = pd.to_numeric(rice_df['Rainfall'],errors = 'coerce')

# %%
rice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Element             59 non-null     float64
#  1   Aman_Rice           54 non-null     float64
#  2   AUS_Rice            54 non-null     float64
#  3   Boro_Rice           54 non-null     float64
#  4   Gross_Area          59 non-null     float64
#  5   Aman_Production     54 non-null     float64
#  6   AUS_Production      54 non-null     float64
#  7   Boro_Production     54 non-null     float64
#  8   Total_Production    59 non-null     float64
#  9   Average_Yeild_Rate  59 non-null     float64
#  10  Temperature         59 non-null     float64
#  11  Rainfall            59 non-null     float64
# dtypes: float64(12)
# memory usage: 5.8 KB

# %%
rice_df.head()
# Out:
#    Element  Aman_Rice  AUS_Rice  Boro_Rice  Gross_Area  Aman_Production  \
# 0      NaN        NaN       NaN        NaN         NaN              NaN
# 1   1961.0      48.34     28.80       7.66        84.8            78.54
# 2   1962.0      49.53     29.50       7.87        86.9            72.44
# 3   1963.0      51.36     30.60       8.14        90.1            86.76
# 4   1964.0      52.60     31.38       8.32        92.3            85.77
#
#    AUS_Production  Boro_Production  Total_Production  Average_Yeild_Rate  \
# 0             NaN              NaN               NaN                 NaN
# 1           37.40            14.97            130.91                1.54
# 2           34.49            12.59            120.73                1.39
# 3           41.31            16.53            144.60                1.60
# 4           40.84            14.91            142.95                1.55
#
#    Temperature  Rainfall
# 0          NaN       NaN
# 1        25.18    211.68
# 2        25.16    179.08
# 3        25.28    189.57
# 4        25.44    209.28

# %%
plt.scatter(x='Temperature',y='Total_Production', data=rice_df, c='b', label='Total_P')
plt.scatter(x='Temperature',y='Average_Yeild_Rate', data=rice_df, c='r', marker='*', label='Avg_rate')
plt.legend()
plt.xlabel('Temperature')
plt.ylabel('Total Production and Average rate')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total Production and Average rate')

# %%
plt.scatter(x='Temperature',y='Aman_Production', data=rice_df, c='g', label='Aman_P')
plt.scatter(x='Temperature',y='AUS_Production', data=rice_df, c='k', label='AUS_P')
plt.scatter(x='Temperature',y='Boro_Production', data=rice_df, c='b', label='Boro_P')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.lmplot(x="Element", y="Total_Production", data=rice_df)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.xlabel("Temperature")
plt.ylabel("")

plt.title("Temeperature vs Production")


plt.plot(rice_df['Aman_Production'])
plt.plot(rice_df['AUS_Production'])
plt.plot(rice_df['Boro_Production'])
plt.plot(rice_df['Total_Production'])
# Out:
# <img src="data:image/png;base64,..." width="640">
