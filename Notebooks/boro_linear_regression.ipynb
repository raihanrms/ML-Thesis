# %% [markdown]
# # **Linear Regression Model in Python**

# %% [markdown]
# ## **Load the Rice Dataset** (from local drive)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f8cac39-ee5e-4fcd-ad03-0b770b31f76b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f8cac39-ee5e-4fcd-ad03-0b770b31f76b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Statistics_of_BORO_Rice_(Husked_Rice).csv to Statistics_of_BORO_Rice_(Husked_Rice).csv

# %% [markdown]
# ### **Import library**

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Load dataset**

# %%
import pandas as pd 
import io

# %% [markdown]
# ### **Read in CSV file**

# %%
df = pd.read_csv('Statistics_of_BORO_Rice_(Husked_Rice).csv')
df.head()

#print(df.head())

plt.scatter(df['Area(Lac_Hectare'],df['TotalProduction(Lac_M_Ton)'])

# %%
X = df[['Area(Lac_Hectare']]
Y = df['TotalProduction(Lac_M_Ton)']

# %% [markdown]
# ## **Data split**

# %% [markdown]
# ### **Import library**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Perform Data split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
#X_train,Y_train

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

#import numpy as np
#predict = np.array([25.99, 37.62, 10.94, 11.6,  38.45, 40.66, 26.03, 26.64, 25.48, 11.62, 47.6, 11.48, 42.58, 15.75, 25.81, 15.34, 19.63, 16.53, 14.33, 47.91, 10.5,  37.71, 47.71, 10.72, 8.84, 26.35, 40.64, 27.83,  9.85, 39.44, 47.78, 48.4,  24.39, 48.1,  36.52, 47.16])

#predict = predict.reshape(-1,1)
#predict.shape

clf.fit(X_train,Y_train)

clf.predict(X_test)
# Out:
# array([  8.06047154,  78.00579775, 136.68589113, 171.74262313,
#         92.25547658,  35.38286459, 174.34875908,  40.38496424,
#         80.14955474])

# %% [markdown]
# ### **Data dimension**

# %%
X_train.shape, Y_train.shape
# Out:
# ((36, 1), (36,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((9, 1), (9,))

# %% [markdown]
# ## **Linear Regression Model**

# %% [markdown]
# ### **Import library**

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### **Build linear regression**

# %% [markdown]
# #### Defines the regression model

# %%
model = linear_model.LinearRegression()

# %% [markdown]
# #### Build training model

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# #### Apply trained model to make prediction (on test set)

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ## **Prediction results**

# %% [markdown]
# ### **Print model performance**

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [4.20344508]
# Intercept: -29.097983003631214
# Mean squared error (MSE): 125.76
# Coefficient of determination (R^2): 0.97

# %% [markdown]
# ### **String formatting**

# %% [markdown]
# By default r2_score returns a floating number ([more details](https://docs.scipy.org/doc/numpy-1.13.0/user/basics.types.html))

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.965220523797422

# %%
r2_score(Y_test, Y_pred).dtype
# Out:
# dtype('float64')

# %% [markdown]
# We will be using the modulo operator to format the numbers by rounding it off.

# %%
'%f' % 0.523810833536016
# Out:
# '0.523811'

# %% [markdown]
# We will now round it off to 3 digits

# %%
'%.3f' % 0.523810833536016
# Out:
# '0.524'

# %% [markdown]
# We will now round it off to 2 digits

# %%
'%.2f' % 0.523810833536016
# Out:
# '0.52'

# %% [markdown]
# ## **Scatter plots**

# %% [markdown]
# ### **Import library**

# %%
import seaborn as sns

# %% [markdown]
# ### **Make scatter plot**

# %% [markdown]
# #### The Data

# %%
Y_test
# Out:
# 1      17.37
# 20     63.57
# 33    128.37
# 39    183.41
# 27     81.45
# 15     36.71
# 44    191.92
# 16     40.10
# 22     65.86
# Name: TotalProduction(Lac_M_Ton), dtype: float64

# %%
import numpy as np
np.array(Y_test)
# Out:
# array([ 17.37,  63.57, 128.37, 183.41,  81.45,  36.71, 191.92,  40.1 ,
#         65.86])

# %%
Y_pred
# Out:
# array([  8.06047154,  78.00579775, 136.68589113, 171.74262313,
#         92.25547658,  35.38286459, 174.34875908,  40.38496424,
#         80.14955474])

# %% [markdown]
# #### Making the scatter plot

# %%
sns.scatterplot(Y_test, Y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(Y_test, Y_pred, marker="+")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(Y_test, Y_pred, alpha=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
