# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-acb58f0f-eb17-47af-bb4a-c850ef824ead" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acb58f0f-eb17-47af-bb4a-c850ef824ead">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Year_wise.csv to Year_wise.csv

# %%
rice_df=pd.read_csv("Year_wise.csv")
rice_df
# Out:
#    Element Aman_Rice AUS_Rice  ... Average_Yeild_Rate Temperature Rainfall
# 0     Year    Lac_Ha   Lac_Ha  ...           M.Ton/Ha     Celsius       MM
# 1     1961     48.34     28.8  ...               1.54       25.18   211.68
# 2     1962     49.53     29.5  ...               1.39       25.16   179.08
# 3     1963     51.36     30.6  ...                1.6       25.28   189.57
# 4     1964      52.6    31.38  ...               1.55       25.44   209.28
# ..     ...       ...      ...  ...                ...         ...      ...
# 56    2016       NaN      NaN  ...              3.511       25.73   176.64
# 57    2017       NaN      NaN  ...              3.832        25.5   228.56
# 58    2018       NaN      NaN  ...              3.853       25.11   151.89
# 59    2019       NaN      NaN  ...              3.866       25.44   169.11
# 60     NaN       NaN      NaN  ...                NaN         NaN      NaN
#
# [61 rows x 12 columns]

# %%
rice_df.dtypes
# Out:
# Element               object
# Aman_Rice             object
# AUS_Rice              object
# Boro_Rice             object
# Gross_Area            object
# Aman_Production       object
# AUS_Production        object
# Boro_Production       object
# Total_Production      object
# Average_Yeild_Rate    object
# Temperature           object
# Rainfall              object
# dtype: object

# %%
rice_df['Element'] = pd.to_numeric(rice_df['Element'],errors = 'coerce')
rice_df['Aman_Rice'] = pd.to_numeric(rice_df['Aman_Rice'],errors = 'coerce')
rice_df['AUS_Rice'] = pd.to_numeric(rice_df['AUS_Rice'],errors = 'coerce')
rice_df['Boro_Rice'] = pd.to_numeric(rice_df['Boro_Rice'],errors = 'coerce')
rice_df['Gross_Area'] = pd.to_numeric(rice_df['Gross_Area'],errors = 'coerce')
rice_df['Aman_Production'] = pd.to_numeric(rice_df['Aman_Production'],errors = 'coerce')
rice_df['AUS_Production'] = pd.to_numeric(rice_df['AUS_Production'],errors = 'coerce')
rice_df['Boro_Production'] = pd.to_numeric(rice_df['Boro_Production'],errors = 'coerce')
rice_df['Total_Production'] = pd.to_numeric(rice_df['Total_Production'],errors = 'coerce')
rice_df['Average_Yeild_Rate'] = pd.to_numeric(rice_df['Average_Yeild_Rate'],errors = 'coerce')
rice_df['Temperature'] = pd.to_numeric(rice_df['Temperature'],errors = 'coerce')
rice_df['Rainfall'] = pd.to_numeric(rice_df['Rainfall'],errors = 'coerce')

# %%
rice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Element             59 non-null     float64
#  1   Aman_Rice           54 non-null     float64
#  2   AUS_Rice            54 non-null     float64
#  3   Boro_Rice           54 non-null     float64
#  4   Gross_Area          59 non-null     float64
#  5   Aman_Production     54 non-null     float64
#  6   AUS_Production      54 non-null     float64
#  7   Boro_Production     54 non-null     float64
#  8   Total_Production    59 non-null     float64
#  9   Average_Yeild_Rate  59 non-null     float64
#  10  Temperature         59 non-null     float64
#  11  Rainfall            59 non-null     float64
# dtypes: float64(12)
# memory usage: 5.8 KB

# %%
rice_df.head()
# Out:
#    Element  Aman_Rice  AUS_Rice  ...  Average_Yeild_Rate  Temperature  Rainfall
# 0      NaN        NaN       NaN  ...                 NaN          NaN       NaN
# 1   1961.0      48.34     28.80  ...                1.54        25.18    211.68
# 2   1962.0      49.53     29.50  ...                1.39        25.16    179.08
# 3   1963.0      51.36     30.60  ...                1.60        25.28    189.57
# 4   1964.0      52.60     31.38  ...                1.55        25.44    209.28
#
# [5 rows x 12 columns]

# %%
plt.scatter(x='Total_Production', y='Temperature', data=rice_df, c='b', label='Total_P')
plt.scatter(x='Average_Yeild_Rate', y='Temperature', data=rice_df, c='r', marker='*', label='Avg_rate')
plt.legend()
plt.xlabel('Temperature')
plt.ylabel('Total Production and Average rate')
# Out:
# Text(-3.9305555555555554, 0.5, 'Total Production and Average rate')

# %%
plt.scatter(x='Aman_Production',y='Temperature', data=rice_df, c='g', label='Aman_P')
plt.scatter(x='AUS_Production',y='Temperature', data=rice_df, c='k', label='AUS_P')
plt.scatter(x='Boro_Production',y='Temperature', data=rice_df, c='b', label='Boro_P')

plt.legend()

# %%
sns.lmplot(x="Total_Production", y="Element", data=rice_df)
# Out:
# <div id='72e697d7-69ed-40c4-9bd1-fa496e54c307'></div>

# %%
plt.xlabel("Temperature")
plt.ylabel("Total_Production")

plt.title("Temeperature vs Production")


plt.plot(rice_df['Aman_Production'])
plt.plot(rice_df['AUS_Production'])
plt.plot(rice_df['Boro_Production'])
plt.plot(rice_df['Total_Production'])
