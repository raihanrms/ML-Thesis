# %% [markdown]
# **Importing the libraries**

# %% [markdown]
# # New section

# %%
import cv2 as cv
import numpy as np
import sys
import skimage
from skimage import data
import skimage.io
import skimage.viewer
from matplotlib import pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Viewer requires Qt
#   import sys

# %% [markdown]
# **Generating the image**

# %%
check = np.zeros((80,80), np.uint(0))
check[10::20, 10::20] = 1
check[10::20, ::200] = 1

plt.xticks([])
plt.yticks([])

data = plt.imshow(check, cmap='gray', interpolation='nearest')

# %% [markdown]
# **Loading the image and applying filters**

# %%
img = cv.imread('/content/download1.png')

# 5x5 smoothing average mask or lowpass filter
#blur = cv.blur(img,(3,3))

# Display the output
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
#plt.subplot(122),plt.imshow(img),plt.title('Averaging')
#plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **Generating Histogram**

# %%
plt.hist(img.ravel(),bins = 1, range = [0,256])

plt.show()
