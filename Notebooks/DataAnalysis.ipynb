# %% [markdown]
# # Data Analysis of the transposed dataset
# ###*Area, production, yield rate, temperature, rainfall*

# %% [markdown]
# ### Uploading dataset
# *Uploaded transposed dataset named Year_wise_T.csv*

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fbfb9205-8481-4f9e-a18e-f41482c31fdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbfb9205-8481-4f9e-a18e-f41482c31fdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Year_wise_T.csv to Year_wise_T.csv

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading and printing all the information

# %%
rice_production_data = pd.read_csv("Year_wise_T.csv", index_col='Element')
print(rice_production_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, Aman_Rice to Rainfall
# Data columns (total 59 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1961    11 non-null     float64
#  1   1962    11 non-null     float64
#  2   1963    11 non-null     float64
#  3   1964    11 non-null     float64
#  4   1965    11 non-null     float64
#  5   1966    11 non-null     float64
#  6   1967    11 non-null     float64
#  7   1968    11 non-null     float64
#  8   1969    11 non-null     float64
#  9   1970    11 non-null     float64
#  10  1971    11 non-null     float64
#  11  1972    11 non-null     float64
#  12  1973    11 non-null     float64
#  13  1974    11 non-null     float64
#  14  1975    11 non-null     float64
#  15  1976    11 non-null     float64
#  16  1977    11 non-null     float64
#  17  1978    11 non-null     float64
#  18  1979    11 non-null     float64
#  19  1980    11 non-null     float64
# ...

# %% [markdown]
# ### Printing the data

# %%
print(rice_production_data)
# Out:
#                       1961    1962    1963  ...     2017     2018     2019
# Element                                     ...
# Aman_Rice            48.34   49.53   51.36  ...      NaN      NaN      NaN
# AUS_Rice             28.80   29.50   30.60  ...      NaN      NaN      NaN
# Boro_Rice             7.66    7.87    8.14  ...      NaN      NaN      NaN
# Gross_Area           84.80   86.90   90.10  ...  115.150  115.160  115.170
# Aman_Production      78.54   72.44   86.76  ...      NaN      NaN      NaN
# AUS_Production       37.40   34.49   41.31  ...      NaN      NaN      NaN
# Boro_Production      14.97   12.59   16.53  ...      NaN      NaN      NaN
# Total_Production    130.91  120.73  144.60  ...  441.360  443.790  445.330
# Average_Yield_Rate    1.54    1.39    1.60  ...    3.832    3.853    3.866
# Temperature          25.18   25.16   25.28  ...   25.500   25.110   25.440
# Rainfall            211.68  179.08  189.57  ...  228.560  151.890  169.110
#
# ...

# %% [markdown]
# ### Dropping the nan values
# *Don't drop it now, it just removes the entire row, will fill the data later*

# %%
'''
dropping all the rows with NaN values
rice_production_data = rice_production_data.dropna()
print(rice_production_data)
'''
# Out:
# '\ndropping all the rows with NaN values\nrice_production_data = rice_production_data.dropna()\nprint(rice_production_data)\n'

# %% [markdown]
# ### Plots of individual data together

# %%
'''
rice_production_data.loc['Aman_Rice',:].plot()
rice_production_data.loc['AUS_Rice',:].plot()
rice_production_data.loc['Boro_Rice',:].plot()
rice_production_data.loc['Gross_Area',:].plot()
'''
rice_production_data.loc['Aman_Production',:].plot()
rice_production_data.loc['AUS_Production',:].plot()
rice_production_data.loc['Boro_Production',:].plot()
rice_production_data.loc['Total_Production',:].plot()

rice_production_data.loc['Average_Yield_Rate',:].plot()

'''
rice_production_data.loc['Temperature',:].plot()
rice_production_data.loc['Rainfall',:].plot()
'''
plt.legend(loc='upper left')

# %% [markdown]
# ### Printing the dataframe

# %%
print(rice_production_data.index)
# Out:
# Index(['Aman_Rice', 'AUS_Rice', 'Boro_Rice', 'Gross_Area', 'Aman_Production',
#        'AUS_Production', 'Boro_Production', 'Total_Production',
#        'Average_Yield_Rate', 'Temperature', 'Rainfall'],
#       dtype='object', name='Element')

# %% [markdown]
# ### Transposed the data

# %%
# transpose the dataset
print(rice_production_data.T)
# Out:
# Element  Aman_Rice  AUS_Rice  ...  Temperature  Rainfall
# 1961         48.34     28.80  ...        25.18    211.68
# 1962         49.53     29.50  ...        25.16    179.08
# 1963         51.36     30.60  ...        25.28    189.57
# 1964         52.60     31.38  ...        25.44    209.28
# 1965         53.35     31.82  ...        25.16    198.27
# 1966         51.69     30.80  ...        25.49    177.89
# 1967         56.36     33.62  ...        25.10    181.23
# 1968         55.53     33.12  ...        25.49    210.46
# 1969         58.78     35.06  ...        25.37    189.28
# 1970         57.40     31.91  ...        25.27    220.73
# 1971         54.74     30.02  ...        24.68    177.08
# 1972         57.14     29.30  ...        25.19    143.15
# 1973         57.19     31.08  ...        25.28    212.16
# 1974         54.51     31.80  ...        24.98    223.93
# 1975         57.61     34.21  ...        25.16    185.38
# ...

# %% [markdown]
# ### Individual Plots

# %%
# Get current size of figure
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: current size
print("Current size:", fig_size)
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
# plot the transposed dataset
rice_production_data.T.plot(subplots=True,layout=(3,4))
plt.xticks(rotation=45)
plt.tight_layout()
# Out:
# Current size: [6.0, 4.0]
