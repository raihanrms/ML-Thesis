# %% [markdown]
# # **Linear Regression Model in Python**

# %% [markdown]
# ## **Load the Rice Dataset** (from local drive)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c30d8a3-c731-4ac2-8588-5a94fdf126ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c30d8a3-c731-4ac2-8588-5a94fdf126ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Statistics_of_Aman_Rice_(Husked_Rice).csv to Statistics_of_Aman_Rice_(Husked_Rice).csv

# %% [markdown]
# ### **Import library**

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Load dataset**

# %%
import pandas as pd 
import io

# %% [markdown]
# ### **Read in CSV file**

# %%
df = pd.read_csv('Statistics_of_Aman_Rice_(Husked_Rice).csv')
df.head()

print(df.head())

plt.scatter(df['Area(Lac_Hectare)'], df['TotalProduction(Lac_M_Ton)'])
# Out:
#   FinacialYear  ...  YieldRate(M.ton_Hectare)
# 0      1970-71  ...                     1.013
# 1      1971-72  ...                     1.041
# 2      1972-73  ...                     0.978
# 3      1973-74  ...                     1.171
# 4      1974-75  ...                     1.101
#
# [5 rows x 6 columns]

# %%
X = df[['Area(Lac_Hectare)']]
Y = df['TotalProduction(Lac_M_Ton)']

# %% [markdown]
# ## **Data split**

# %% [markdown]
# ### **Import library**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Perform Data split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
#X_train,Y_train

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

clf.fit(X_train,Y_train)

clf.predict(X_test)
# Out:
# array([89.28522536, 88.89243381, 90.2942933 , 89.73896732, 88.87888927,
#        93.34181395, 88.97370103, 88.58090948, 86.82011977])

# %% [markdown]
# ### **Data dimension**

# %%
X_train.shape, Y_train.shape
# Out:
# ((36, 1), (36,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((9, 1), (9,))

# %% [markdown]
# ## **Linear Regression Model**

# %% [markdown]
# ### **Import library**

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### **Build linear regression**

# %% [markdown]
# #### Defines the regression model

# %%
model = linear_model.LinearRegression()

# %% [markdown]
# #### Build training model

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# #### Apply trained model to make prediction (on test set)

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ## **Prediction results**

# %% [markdown]
# ### **Print model performance**

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [-0.67722681]
# Intercept: 127.52822328136621
# Mean squared error (MSE): 353.00
# Coefficient of determination (R^2): -0.19

# %% [markdown]
# ### **String formatting**

# %% [markdown]
# By default r2_score returns a floating number ([more details](https://docs.scipy.org/doc/numpy-1.13.0/user/basics.types.html))

# %%
r2_score(Y_test, Y_pred)
# Out:
# -0.18597733900909286

# %%
r2_score(Y_test, Y_pred).dtype
# Out:
# dtype('float64')

# %% [markdown]
# We will be using the modulo operator to format the numbers by rounding it off.

# %%
'%f' % 0.523810833536016
# Out:
# '0.523811'

# %% [markdown]
# We will now round it off to 3 digits

# %%
'%.3f' % 0.523810833536016
# Out:
# '0.524'

# %% [markdown]
# We will now round it off to 2 digits

# %%
'%.2f' % 0.523810833536016
# Out:
# '0.52'

# %% [markdown]
# ## **Scatter plots**

# %% [markdown]
# ### **Import library**

# %%
import seaborn as sns

# %% [markdown]
# ### **Make scatter plot**

# %% [markdown]
# #### The Data

# %%
Y_test
# Out:
# 31    107.26
# 29    103.06
# 38    116.13
# 41    127.98
# 7      74.24
# 37     96.62
# 21     92.69
# 23     94.29
# 11     70.95
# Name: TotalProduction(Lac_M_Ton), dtype: float64

# %%
import numpy as np
np.array(Y_test)
# Out:
# array([107.26, 103.06, 116.13, 127.98,  74.24,  96.62,  92.69,  94.29,
#         70.95])

# %%
Y_pred
# Out:
# array([89.28522536, 88.89243381, 90.2942933 , 89.73896732, 88.87888927,
#        93.34181395, 88.97370103, 88.58090948, 86.82011977])

# %% [markdown]
# #### Making the scatter plot

# %%
sns.scatterplot(Y_test, Y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(Y_test, Y_pred, marker="+")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(Y_test, Y_pred, alpha=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
